# %%
pip install craigslistscraper
# Out:
# Requirement already satisfied: craigslistscraper in c:\anaconda\lib\site-packages (1.1.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: beautifulsoup4 in c:\anaconda\lib\site-packages (from craigslistscraper) (4.9.3)
# Requirement already satisfied: requests in c:\anaconda\lib\site-packages (from craigslistscraper) (2.32.2)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconda\lib\site-packages (from beautifulsoup4->craigslistscraper) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda\lib\site-packages (from requests->craigslistscraper) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda\lib\site-packages (from requests->craigslistscraper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda\lib\site-packages (from requests->craigslistscraper) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda\lib\site-packages (from requests->craigslistscraper) (2024.8.30)

# %%
# import necessary libraries
import craigslistscraper as cs
import json
import pandas as pd
import time

# %%
# Define the search.
search = cs.Search(
    query = "nvidia | amd",
    city = "atlanta",
    category = "syp"
)

# %%
#Setting up some variables to name our final Excel file. Feel free to adjust these.

base_path = r'C:\Users\TCF GIS\Documents\craigslistads'
TodaysDate = time.strftime("%b-%d-%Y-%H-%M-%S")

df.to_excel(base_path + "\\" + TodaysDate +".xlsx", index=False)

# %%
# Create an empty pandas dataframe. We'll dump our data in here later.
df = pd.DataFrame()

# %%
# Fetch the html from the server. The status will let you know if the website is down, or other problems. 
status = search.fetch()
if status != 200:
    raise Exception(f"Unable to fetch search with status <{status}>.")

# %%
# We'll loop through the ads and add them to the pandas dataframe one by one.
for ad in search.ads:
    # Fetch additional information about each ad. Check the status again.
    status = ad.fetch()
    if status != 200:
        print(f"Unable to fetch ad '{ad.title}' with status <{status}>.")
        continue

    # There is a to_dict() method for convenience. 
    data = ad.to_dict()
    
    # json.dumps is merely for pretty printing. 
    print(json.dumps(data, indent = 4))

    # This is where the ads finally get added to the dataframe.
    df = pd.concat([df, pd.DataFrame([data])], ignore_index=True)
# Out:
# {
#     "url": "https://atlanta.craigslist.org/nat/sop/d/kennesaw-amd-ryzen-processor/7790286837.html",
#     "price": 60.0,
#     "title": "AMD Ryzen 5 3600 Processor",
#     "d_pid": 7790286837,
#     "description": "\n\n\n\n\nLocal pick up. Price is FIRM.\n\nGOOD - AMD Ryzen 5 3600 Processor\n",
#     "image_urls": [],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/nat/sop/d/kennesaw-low-profile-nvidia-geforce-gt/7785049584.html",
#     "price": 40.0,
#     "title": "LOW PROFILE - NVIDIA GeForce GT 730 1GB video card",
#     "d_pid": 7785049584,
#     "description": "\n\n\n\n\nLocal pickup. Price is FIRM.\n\nLOW PROFILE - NVIDIA GeForce GT 730 1GB video card\n\nDVI and HDMI out\n",
#     "image_urls": [],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/nat/sop/d/kennesaw-evga-nvidia-geforce-gts-250/7779723507.html",
#     "price": 25.0,
#     "title": "EVGA NVIDIA GeForce GTS 250 Retro Graphics Card",
#     "d_pid": 7779723507,
#     "description": "\n\n\n\n\nLocal pick up. Price is FIRM.\n\nEVGA NVIDIA GeForce GTS 250 Retro Graphics Card\n",
#     "image_urls": [],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/nat/sop/d/cumming-amd-radeon-6900xt/7787832211.html",
#     "price": 300.0,
#     "title": "AMD Radeon 6900xt",
#     "d_pid": 7787832211,
#     "description": "\n\n\n\n\nVery lightly used . Excellent condition gpu. \nComes with original packaging \n\nLet me know if interested . Open to reasonable offers\n",
#     "image_urls": [
#         "https://images.craigslist.org/00202_frW7Obj9tki_0lM0CI_600x450.jpg",
#         "https://images.craigslist.org/00w0w_9G9Lh24XFlk_0lM0CI_600x450.jpg",
#         "https://images.craigslist.org/01111_8o842E9KnP9_0lM0CI_600x450.jpg"
#     ],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/atl/sop/d/decatur-new-msi-geforce-rtx-4090-gaming/7787669170.html",
#     "price": 830.0,
#     "title": "New MSi GeForce RTX 4090 Gaming X TRIO 24GB GDDR6X Graphics Card",
#     "d_pid": 7787669170,
#     "description": "\n\n\n\n\nNew MSi GeForce RTX 4090 Gaming X TRIO 24GB GDDR6X Graphics Card 912-V510-296\nOriginal Box with everything inside same as you would buy it in the store.\n    ",
#     "image_urls": [],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/atl/sop/d/decatur-asus-tuf-nvidia-geforce-rtx/7787671295.html",
#     "price": 950.0,
#     "title": "Asus Tuf NVIDIA GeForce RTX 4090 GAMING OC 24GB GDDR6X Video GPU Card",
#     "d_pid": 7787671295,
#     "description": "\n\n\n\n\nCall or text me for fastest response. Ready to meet or even ship.\nAsus Tuf Gaming NVIDIA GeForce RTX 4090 GAMING OC 24GB GDDR6X Video GPU Card\nFlawless working and cosmetic condition in original box with power adapter and mounting brackets. Asus Tuf Gaming DirectX 12 Ultimate, OpenGL 4.6 MPN GV-N4090GAMING-OC-24GD NVIDIA GeForce RTX 4090 PCI Express 4.0 x16 16-Pin PCI-E 16384 CUDA Processors 384-bit memory bus 2535MHz Core Clock Speed 1000 Watts Recommended Power Supply.\n    ",
#     "image_urls": [
#         "https://images.craigslist.org/01515_dQ3erNlR0IL_0c607z_600x450.jpg",
#         "https://images.craigslist.org/00m0m_fZmpLKyuPoP_09V06J_600x450.jpg",
#         "https://images.craigslist.org/00J0J_bLxNg3iv9nM_0pO0ew_600x450.jpg"
#     ],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/atl/sop/d/decatur-brand-new-asus-nvidia-rog-strix/7787670226.html",
#     "price": 1200.0,
#     "title": "BRAND NEW ASUS NVIDIA ROG STRIX OC 4090 GDDR6X GRAPHICS CARD FOR SALE",
#     "d_pid": 7787670226,
#     "description": "\n\n\n\n\nTHIS IS A BRAND NEW SEALED ASUS NVIDIA ROG STRIX OC 4090 GDDR6X GRAPHICS CARD FOR SALE. I AM THE ORIGINAL PURCHASER AND PROOF OF PURCHASE CAN BE SHOWN . IT IS FOR LOCAL MEET UP IN THE LOS ANGELES AREA AT A LOCAL POLICE STATION FOR BOTH PARTIES SAFETY. THIS IS HANDS DOWN THE BEST GRAPHICS CARD MONEY CAN BUY . IT IS SOLD OUT EVERYWHERE . IF MONEY IS NO OBJECT, THIS IS THE GRAPHICS CARD YOU WANT TO GET! From top to bottom, the ROG Strix GeForce RTX 4090 OC version has been radically improved to accommodate the impressive new Ampere chips from NVIDIA and to deliver the next wave of gaming performance innovation to the market. Thick looks, complete feature set, top cooling performance, and room within the bios limits to enjoy overclocking if you want to go crazy.\n",
#     "image_urls": [
#         "https://images.craigslist.org/00x0x_jyr3V7ce7Dg_0jm0eq_600x450.jpg",
#         "https://images.craigslist.org/00h0h_5dUBJniXgIo_0jm0cV_600x450.jpg",
#         "https://images.craigslist.org/00707_jgGSDzl4oxI_0ca0ew_600x450.jpg",
#         "https://images.craigslist.org/00L0L_l4HgCyKp9GR_0jm0c0_600x450.jpg",
#         "https://images.craigslist.org/00i0i_3udXFscDmHl_0iP0ew_600x450.jpg",
#         "https://images.craigslist.org/00a0a_2fAH2GYy6ZW_0jm0b5_600x450.jpg"
#     ],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/atl/sop/d/decatur-msi-geforce-rtx-like-new/7785564469.html",
#     "price": 1150.0,
#     "title": "MSI GeForce RTX 4090 - LIKE NEW",
#     "d_pid": 7785564469,
#     "description": "\n\n\n\n\nI no longer have time to play games and thus no longer need a 4090 and could use the extra money. This graphics card was installed on my gaming computer, which has only been booted up 4-5 times since installing the card. In my limited experience with this beast of a card, it can run any game at 4K at maximum settings. Recently tested to be fully functioning without problems.\n\n- Non-smoking household\n- Original box is included\n- Looking for $1850 or best offer (Currently retailing for $2000 in retail stores/online)\n    ",
#     "image_urls": [
#         "https://images.craigslist.org/00M0M_3Gln2EhUCxN_0jm0ew_600x450.jpg",
#         "https://images.craigslist.org/01010_j6FCIk4VKlX_0jm0ew_600x450.jpg",
#         "https://images.craigslist.org/00b0b_74vmUKYIPGr_0jm0ew_600x450.jpg",
#         "https://images.craigslist.org/00L0L_lPFf4RO1gaw_0gP0dj_600x450.jpg"
#     ],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/atl/sop/d/decatur-brand-new-asus-nvidia-rog-strix/7785562591.html",
#     "price": 1330.0,
#     "title": "BRAND NEW ASUS NVIDIA ROG STRIX OC 4090 GDDR6X GRAPHICS CARD FOR SALE",
#     "d_pid": 7785562591,
#     "description": "\n\n\n\n\nTHIS IS A BRAND NEW SEALED ASUS NVIDIA ROG STRIX OC 4090 GDDR6X GRAPHICS CARD FOR SALE. I AM THE ORIGINAL PURCHASER AND PROOF OF PURCHASE CAN BE SHOWN . IT IS FOR LOCAL MEET UP IN THE LOS ANGELES AREA AT A LOCAL POLICE STATION FOR BOTH PARTIES SAFETY. THIS IS HANDS DOWN THE BEST GRAPHICS CARD MONEY CAN BUY . IT IS SOLD OUT EVERYWHERE . IF MONEY IS NO OBJECT, THIS IS THE GRAPHICS CARD YOU WANT TO GET! From top to bottom, the ROG Strix GeForce RTX 4090 OC version has been radically improved to accommodate the impressive new Ampere chips from NVIDIA and to deliver the next wave of gaming performance innovation to the market. Thick looks, complete feature set, top cooling performance, and room within the bios limits to enjoy overclocking if you want to go crazy.\n",
#     "image_urls": [
#         "https://images.craigslist.org/00x0x_jyr3V7ce7Dg_0jm0eq_600x450.jpg",
#         "https://images.craigslist.org/00707_jgGSDzl4oxI_0ca0ew_600x450.jpg",
#         "https://images.craigslist.org/00L0L_l4HgCyKp9GR_0jm0c0_600x450.jpg",
#         "https://images.craigslist.org/00i0i_3udXFscDmHl_0iP0ew_600x450.jpg",
#         "https://images.craigslist.org/00a0a_2fAH2GYy6ZW_0jm0b5_600x450.jpg"
#     ],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/atl/sop/d/decatur-new-msi-geforce-rtx-4090-gaming/7785539086.html",
#     "price": 830.0,
#     "title": "New MSi GeForce RTX 4090 Gaming X TRIO 24GB GDDR6X Graphics Card",
#     "d_pid": 7785539086,
#     "description": "\n\n\n\n\nNew MSi GeForce RTX 4090 Gaming X TRIO 24GB GDDR6X Graphics Card 912-V510-296\nOriginal Box with everything inside same as you would buy it in the store.\n    ",
#     "image_urls": [],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/nat/sop/d/alpharetta-nvidia-cmp-90hx-mining-gpu/7777099778.html",
#     "price": 200.0,
#     "title": "nVidia CMP 90HX mining GPU (no video output)",
#     "d_pid": 7777099778,
#     "description": "\n\n\n\n\nGreat condition.  The CMP 90HX is a mining-specific GPU from nVidia, gets hashrates equivalent to an RTX 3080.  It has been copper-modded to keep temperatures down.  Great for triple-mining Alephium+Ergo and Zilliqa, among many other options.\n\nPublic meetup in Roswell/Alpharetta area.  I accept cash, Venmo and crypto.\n",
#     "image_urls": [],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/nat/sop/d/atlanta-radeon-hd-6950/7776460514.html",
#     "price": 10.0,
#     "title": "Radeon HD 6950",
#     "d_pid": 7776460514,
#     "description": "\n\n\n\n\nWorks great!\n",
#     "image_urls": [],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/nat/sop/d/roswell-alienware-aw3420dw-gaming/7785844734.html",
#     "price": 400.0,
#     "title": "Alienware AW3420DW Gaming Ultrawide Monitor (3440x1440, 120hz, G-SYNC)",
#     "d_pid": 7785844734,
#     "description": "\n\n\n\n\nPerfect functional and cosmetic condition - easily does 120hz and supports both G-SYNC and FreeSYNC (works with both Nvidia and AMD graphics cards)! I'm the sole owner, comes from a non-smoking household - monitor has sat in one position and not touched since purchase in late 2020. No dead pixels, no bad backlight bleed. This is a great deal for a great display. One you go Ultrawide, you'll never go back!\n\nPlease email if you are interested, cash (or cashier's check if you want to meet at my bank) accepted with preference to exchange at Roswell Police Department during working hours for our joint comfort and safety.  Webcam or other peripherals shown in picture not included but all cables that came with the monitor are included.  I won't ship it and I'm not interested in trades, contact me for additional questions or pictures/videos.  Thanks!\n\nSpecs and additional info:  https://www.dell.com/ae/p/dell-aw3420dw-monitor/pd?ref=PD_Family\n",
#     "image_urls": [
#         "https://images.craigslist.org/00L0L_kSaVhlva1ZI_0CI0t2_600x450.jpg",
#         "https://images.craigslist.org/00T0T_hrHV6i1DAge_0jy0eB_600x450.jpg"
#     ],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/atl/sop/d/decatur-asus-tuf-nvidia-geforce-rtx/7784473437.html",
#     "price": 800.0,
#     "title": "Asus Tuf NVIDIA GeForce RTX 4090 GAMING OC 24GB GDDR6X Video GPU Card",
#     "d_pid": 7784473437,
#     "description": "\n\n\n\n\nCall or text me for fastest response. Ready to meet or even ship.\nAsus Tuf  Gaming NVIDIA GeForce RTX 4090 GAMING OC 24GB GDDR6X Video GPU Card\nFlawless working and cosmetic condition in original box with power adapter and mounting brackets. Asus Tuf Gaming DirectX 12 Ultimate, OpenGL 4.6 MPN GV-N4090GAMING-OC-24GD NVIDIA GeForce RTX 4090 PCI Express 4.0 x16 16-Pin PCI-E 16384 CUDA Processors 384-bit memory bus 2535MHz Core Clock Speed 1000 Watts Recommended Power Supply.\n    ",
#     "image_urls": [
#         "https://images.craigslist.org/00J0J_bLxNg3iv9nM_0pO0ew_600x450.jpg",
#         "https://images.craigslist.org/00c0c_1MUNkbFyoqn_0ew0pO_600x450.jpg",
#         "https://images.craigslist.org/00H0H_6pY3yv20hUA_0ew0pO_600x450.jpg"
#     ],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/nat/sop/d/kennesaw-amd-ryzen-cpu-hexa-core/7774886331.html",
#     "price": 40.0,
#     "title": "AMD Ryzen 5 1600 CPU Hexa-Core Processor",
#     "d_pid": 7774886331,
#     "description": "\n\n\n\n\nLocal Pick up. Price is FIRM.\n\nAMD Ryzen 5 1600 Hexa-Core Processor\n\nUsed and working condition. Comes from upgraded Computer.\n",
#     "image_urls": [],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/atl/sop/d/atlanta-samsung-49-hdr-curved-gaming/7789159532.html",
#     "price": 400.0,
#     "title": "Samsung 49\" HDR Curved Gaming Monitor",
#     "d_pid": 7789159532,
#     "description": "\n\n\n\n\nSamsung 49\" HDR curved gaming monitor (Model LC49RG90SSNXZA) in excellent condition.\nOne owner, purchased new about 3 yrs. ago - used primarily for audio / video editing.  Includes base as shown in pictures as well as VESA mount (not shown) to mount on monitor arm or wall.\n\nIt is a large monitor so please reference the dimensions on Samsung's website to ensure it fits your needs -  https://www.samsung.com/us/computing/monitors/gaming/49-crg9-dual-qhd-curved-qled-gaming-monitor-lc49rg90ssnxza/\n\nFeatures as follows from Samsung:\n\nDUAL QHD RESOLUTION: The 5120 x 1440 super ultra-wide aspect ratio lets you view content in superfine detail\nHDR1000 & QLED: Has a brightness rating of 1,000 nits and DCI-P3 95%, so colors are pure, bright, and true to life\nIMMERSIVE CURVE: With a Super Ultra-Wide 32:9 ratio, the CRG9 curves around your field of view to immerse you in all the onscreen gaming action\nAMD RADEON FREESYNC2: Effortlessly Smooth Gameplay; Supports HDR content, reduces input latency, and has low framerate compensation\nBUILT FOR SPEED: The 120Hz settings minimize image lag and motion blur; The 60Hz settings let you optimize performance\n\nSelling for $400 firm.  Not interested in any trades so trade inquiries will not be answered.\n\nPicked up in the Midtown ATL area only.\n",
#     "image_urls": [
#         "https://images.craigslist.org/00z0z_7YDPg0jkUrC_0CI0t2_600x450.jpg",
#         "https://images.craigslist.org/00J0J_hRAz1VIrgNF_0CI0t2_600x450.jpg",
#         "https://images.craigslist.org/00G0G_3eOHuSkMFUI_0CI0t2_600x450.jpg",
#         "https://images.craigslist.org/00D0D_hsFFVWBSM7H_0CI0t2_600x450.jpg",
#         "https://images.craigslist.org/01111_b1sWdK0qu6o_0CI0t2_600x450.jpg",
#         "https://images.craigslist.org/00y0y_3ENW8tcJozV_0CI0t2_600x450.jpg"
#     ],
#     "attributes": {}
# }
# {
#     "url": "https://atlanta.craigslist.org/nat/sop/d/lilburn-pny-rtx-3070-xlr8-gaming-epic/7781463987.html",
#     "price": 275.0,
#     "title": "PNY RTX 3070 XLR8 Gaming EPIC-X RGB Triple Fan Edition 8Gb",
#     "d_pid": 7781463987,
#     "description": "\n\n\n\n\nExcellent deal on a barely used PNY GeForce RTX 3070 XLR8 Gaming EPIC-X RGB Triple Fan Edition graphics card. Was used in a system for 3 months and then switched to another GPU. In like new condition. \n\n$275 cash. Paid $650\nWill meet in person. I do not have the box.\n\nKEY FEATURES\n\n- 2nd Gen Ray Tracing Cores\n- 3rd Gen Tensor Cores\n- PCI Express\u00ae Gen 4\n- Microsoft DirectX\u00ae 12 Ultimate\n- GDDR6 Graphics Memory\n- NVIDIA DLSS\n- NVIDIA\u00ae GeForce Experience\u2122\n- NVIDIA G-SYNC\u00ae\n- NVIDIA GPU Boost\u2122\n- Game Ready Drivers\n- Vulkan RT API, OpenGL 4.6\n- HDCP 2.3\n- VR Ready\n- Supports 4k 120Hz HDR, 8K 60Hz HDR and Variable Refresh Rate as specified in HDMI 2.1\n",
#     "image_urls": [
#         "https://images.craigslist.org/00F0F_18b3VIEyAtx_0oo0ww_600x450.jpg",
#         "https://images.craigslist.org/00A0A_cBFEpNVkWFH_0oo0ww_600x450.jpg",
#         "https://images.craigslist.org/00q0q_fvXFTHCSvA4_0oo0ww_600x450.jpg",
#         "https://images.craigslist.org/00y0y_8ePoCvpYq1C_0oo0ww_600x450.jpg",
#         "https://images.craigslist.org/00L0L_jmy9JKwVnsW_0oo0ww_600x450.jpg"
#     ],
#     "attributes": {}
# }

# %%
# Converting the dataframe to an Excel file and saving it to your specified folder.
# Warning: this will overwrite your file each time you run this.
# 
df.to_excel(base_path + "\\" + TodaysDate +".xlsx", index=False)

# %%
print(df)
# Out:
#                                                   url   price  \
# 0   https://atlanta.craigslist.org/nat/sop/d/kenne...    60.0
# 1   https://atlanta.craigslist.org/nat/sop/d/kenne...    40.0
# 2   https://atlanta.craigslist.org/nat/sop/d/kenne...    25.0
# 3   https://atlanta.craigslist.org/nat/sop/d/cummi...   300.0
# 4   https://atlanta.craigslist.org/atl/sop/d/decat...   830.0
# 5   https://atlanta.craigslist.org/atl/sop/d/decat...   950.0
# 6   https://atlanta.craigslist.org/atl/sop/d/decat...  1200.0
# 7   https://atlanta.craigslist.org/atl/sop/d/decat...  1150.0
# 8   https://atlanta.craigslist.org/atl/sop/d/decat...  1330.0
# 9   https://atlanta.craigslist.org/atl/sop/d/decat...   830.0
# 10  https://atlanta.craigslist.org/nat/sop/d/alpha...   200.0
# 11  https://atlanta.craigslist.org/nat/sop/d/atlan...    10.0
# 12  https://atlanta.craigslist.org/nat/sop/d/roswe...   400.0
# 13  https://atlanta.craigslist.org/atl/sop/d/decat...   800.0
# 14  https://atlanta.craigslist.org/nat/sop/d/kenne...    40.0
# 15  https://atlanta.craigslist.org/atl/sop/d/atlan...   400.0
# 16  https://atlanta.craigslist.org/nat/sop/d/lilbu...   275.0
#
#                                                 title       d_pid  \
# 0                          AMD Ryzen 5 3600 Processor  7790286837
# 1   LOW PROFILE - NVIDIA GeForce GT 730 1GB video ...  7785049584
# 2     EVGA NVIDIA GeForce GTS 250 Retro Graphics Card  7779723507
# 3                                   AMD Radeon 6900xt  7787832211
# 4   New MSi GeForce RTX 4090 Gaming X TRIO 24GB GD...  7787669170
# 5   Asus Tuf NVIDIA GeForce RTX 4090 GAMING OC 24G...  7787671295
# 6   BRAND NEW ASUS NVIDIA ROG STRIX OC 4090 GDDR6X...  7787670226
# 7                     MSI GeForce RTX 4090 - LIKE NEW  7785564469
# 8   BRAND NEW ASUS NVIDIA ROG STRIX OC 4090 GDDR6X...  7785562591
# 9   New MSi GeForce RTX 4090 Gaming X TRIO 24GB GD...  7785539086
# 10       nVidia CMP 90HX mining GPU (no video output)  7777099778
# 11                                     Radeon HD 6950  7776460514
# 12  Alienware AW3420DW Gaming Ultrawide Monitor (3...  7785844734
# 13  Asus Tuf NVIDIA GeForce RTX 4090 GAMING OC 24G...  7784473437
# 14           AMD Ryzen 5 1600 CPU Hexa-Core Processor  7774886331
# 15              Samsung 49" HDR Curved Gaming Monitor  7789159532
# 16  PNY RTX 3070 XLR8 Gaming EPIC-X RGB Triple Fan...  7781463987
#
#                                           description  \
# 0   \n\n\n\n\nLocal pick up. Price is FIRM.\n\nGOO...
# 1   \n\n\n\n\nLocal pickup. Price is FIRM.\n\nLOW ...
# 2   \n\n\n\n\nLocal pick up. Price is FIRM.\n\nEVG...
# 3   \n\n\n\n\nVery lightly used . Excellent condit...
# 4   \n\n\n\n\nNew MSi GeForce RTX 4090 Gaming X TR...
# 5   \n\n\n\n\nCall or text me for fastest response...
# 6   \n\n\n\n\nTHIS IS A BRAND NEW SEALED ASUS NVID...
# 7   \n\n\n\n\nI no longer have time to play games ...
# 8   \n\n\n\n\nTHIS IS A BRAND NEW SEALED ASUS NVID...
# 9   \n\n\n\n\nNew MSi GeForce RTX 4090 Gaming X TR...
# 10  \n\n\n\n\nGreat condition.  The CMP 90HX is a ...
# 11                           \n\n\n\n\nWorks great!\n
# 12  \n\n\n\n\nPerfect functional and cosmetic cond...
# 13  \n\n\n\n\nCall or text me for fastest response...
# 14  \n\n\n\n\nLocal Pick up. Price is FIRM.\n\nAMD...
# 15  \n\n\n\n\nSamsung 49" HDR curved gaming monito...
# 16  \n\n\n\n\nExcellent deal on a barely used PNY ...
#
#                                            image_urls attributes
# 0                                                  []         {}
# 1                                                  []         {}
# 2                                                  []         {}
# 3   [https://images.craigslist.org/00202_frW7Obj9t...         {}
# 4                                                  []         {}
# 5   [https://images.craigslist.org/01515_dQ3erNlR0...         {}
# 6   [https://images.craigslist.org/00x0x_jyr3V7ce7...         {}
# 7   [https://images.craigslist.org/00M0M_3Gln2EhUC...         {}
# 8   [https://images.craigslist.org/00x0x_jyr3V7ce7...         {}
# 9                                                  []         {}
# 10                                                 []         {}
# 11                                                 []         {}
# 12  [https://images.craigslist.org/00L0L_kSaVhlva1...         {}
# 13  [https://images.craigslist.org/00J0J_bLxNg3iv9...         {}
# 14                                                 []         {}
# 15  [https://images.craigslist.org/00z0z_7YDPg0jkU...         {}
# 16  [https://images.craigslist.org/00F0F_18b3VIEyA...         {}
